# %%
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import numpy as np
# ^^^ pyforest auto-imports - don't write above this line

# %%
df=pd.read_csv('C:/Users/Mani/Downloads/COVID-19 Cases.csv', parse_dates=True)
df
# Out:
#         Case_Type  People_Total_Tested_Count  Cases  Difference       Date  \
# 0       Confirmed                        NaN      0           0   2/3/2020
# 1          Deaths                        NaN      0           0   3/1/2020
# 2       Confirmed                        NaN     23           0  4/21/2020
# 3          Deaths                        NaN      0           0  2/11/2020
# 4       Confirmed                        NaN      0           0   2/6/2020
# ...           ...                        ...    ...         ...        ...
# 718075  Confirmed                        NaN      0           0  1/22/2020
# 718076     Deaths                        NaN      0           0  1/22/2020
# 718077     Deaths                        NaN      0           0  1/22/2020
# 718078  Confirmed                        NaN      0           0  1/22/2020
# 718079  Confirmed                        NaN      0           0  1/22/2020
#
# ...

# %%
type(df.Date[0])
# Out:
# str

# %%
df['Date']=pd.to_datetime(df.Date)
df
# Out:
#         Case_Type  People_Total_Tested_Count  Cases  Difference       Date  \
# 0       Confirmed                        NaN      0           0 2020-02-03
# 1          Deaths                        NaN      0           0 2020-03-01
# 2       Confirmed                        NaN     23           0 2020-04-21
# 3          Deaths                        NaN      0           0 2020-02-11
# 4       Confirmed                        NaN      0           0 2020-02-06
# ...           ...                        ...    ...         ...        ...
# 718075  Confirmed                        NaN      0           0 2020-01-22
# 718076     Deaths                        NaN      0           0 2020-01-22
# 718077     Deaths                        NaN      0           0 2020-01-22
# 718078  Confirmed                        NaN      0           0 2020-01-22
# 718079  Confirmed                        NaN      0           0 2020-01-22
#
# ...

# %%
df.isna().sum()
# Out:
# Case_Type                                    0
# People_Total_Tested_Count               715728
# Cases                                        0
# Difference                                   0
# Date                                         0
# Combined_Key                                 0
# Country_Region                               0
# Province_State                           37128
# Admin2                                   54264
# iso2                                       408
# iso3                                       204
# FIPS                                     76092
# Lat                                      21420
# Long                                     21420
# Population_Count                         21420
# People_Hospitalized_Cumulative_Count    715728
# Data_Source                                  0
# Prep_Flow_Runtime                            0
# dtype: int64

# %%
df.Case_Type.value_counts()
# Out:
# Deaths       359040
# Confirmed    359040
# Name: Case_Type, dtype: int64

# %%
pivot_df=df.pivot_table(index=['Country_Region','Combined_Key','Date'],columns=['Case_Type'],values=['Cases'],aggfunc='sum')
pivot_df
# Out:
#                                           Cases
# Case_Type                             Confirmed Deaths
# Country_Region Combined_Key Date
# Afghanistan    Afghanistan  1/22/2020         0      0
#                             1/23/2020         0      0
#                             1/24/2020         0      0
#                             1/25/2020         0      0
#                             1/26/2020         0      0
# ...                                         ...    ...
# Zimbabwe       Zimbabwe     4/7/2020         11      2
#                             4/8/2020         11      3
#                             4/9/2020         11      3
#                             5/1/2020         40      4
#                             5/2/2020         34      4
#
# [359040 rows x 2 columns]

# %%
pivot_df.reset_index(inplace=True)
pivot_df
# Out:
#           Country_Region Combined_Key       Date     Cases
# Case_Type                                        Confirmed Deaths
# 0            Afghanistan  Afghanistan  1/22/2020         0      0
# 1            Afghanistan  Afghanistan  1/23/2020         0      0
# 2            Afghanistan  Afghanistan  1/24/2020         0      0
# 3            Afghanistan  Afghanistan  1/25/2020         0      0
# 4            Afghanistan  Afghanistan  1/26/2020         0      0
# ...                  ...          ...        ...       ...    ...
# 359035          Zimbabwe     Zimbabwe   4/7/2020        11      2
# 359036          Zimbabwe     Zimbabwe   4/8/2020        11      3
# 359037          Zimbabwe     Zimbabwe   4/9/2020        11      3
# 359038          Zimbabwe     Zimbabwe   5/1/2020        40      4
# 359039          Zimbabwe     Zimbabwe   5/2/2020        34      4
#
# [359040 rows x 5 columns]

# %%
pivot_df
# Out:
#           Country_Region Combined_Key       Date     Cases
# Case_Type                                        Confirmed Deaths
# 0            Afghanistan  Afghanistan 2020-01-22         0      0
# 1            Afghanistan  Afghanistan 2020-01-23         0      0
# 2            Afghanistan  Afghanistan 2020-01-24         0      0
# 3            Afghanistan  Afghanistan 2020-01-25         0      0
# 4            Afghanistan  Afghanistan 2020-01-26         0      0
# ...                  ...          ...        ...       ...    ...
# 359035          Zimbabwe     Zimbabwe 2020-04-07        11      2
# 359036          Zimbabwe     Zimbabwe 2020-04-08        11      3
# 359037          Zimbabwe     Zimbabwe 2020-04-09        11      3
# 359038          Zimbabwe     Zimbabwe 2020-05-01        40      4
# 359039          Zimbabwe     Zimbabwe 2020-05-02        34      4
#
# [359040 rows x 5 columns]

# %%
type(pivot_df.Date[0])
# Out:
# str

# %%
pivot_df['Date']=pd.to_datetime(pivot_df.Date)
pivot_df
# Out:
#           Country_Region Combined_Key       Date     Cases
# Case_Type                                        Confirmed Deaths
# 0            Afghanistan  Afghanistan 2020-01-22         0      0
# 1            Afghanistan  Afghanistan 2020-01-23         0      0
# 2            Afghanistan  Afghanistan 2020-01-24         0      0
# 3            Afghanistan  Afghanistan 2020-01-25         0      0
# 4            Afghanistan  Afghanistan 2020-01-26         0      0
# ...                  ...          ...        ...       ...    ...
# 359035          Zimbabwe     Zimbabwe 2020-04-07        11      2
# 359036          Zimbabwe     Zimbabwe 2020-04-08        11      3
# 359037          Zimbabwe     Zimbabwe 2020-04-09        11      3
# 359038          Zimbabwe     Zimbabwe 2020-05-01        40      4
# 359039          Zimbabwe     Zimbabwe 2020-05-02        34      4
#
# [359040 rows x 5 columns]

# %%
pivot_df.isna().sum()
# Out:
#                 Case_Type
# Country_Region               0
# Combined_Key                 0
# Date                         0
# Cases           Confirmed    0
#                 Deaths       0
# dtype: int64

# %%
pivot_df.columns
# Out:
# MultiIndex([('Country_Region',          ''),
#             (  'Combined_Key',          ''),
#             (          'Date',          ''),
#             (         'Cases', 'Confirmed'),
#             (         'Cases',    'Deaths')],
#            names=[None, 'Case_Type'])

# %%
#pivot_df.groupby(['Country_Region']).agg({pivot_df.columns.get_level_values(1)[3] : np.sum})
pivot_df.groupby(['Country_Region']).agg({tuple(pivot_df.Cases.Confirmed) : np.sum})
# Out:
# D:\Anaconda\lib\site-packages\pandas\core\groupby\generic.py:1455: FutureWarning: using a dict with renaming is deprecated and will be removed
# in a future version.
#
# For column-specific groupby renaming, use named aggregation
#
#     >>> df.groupby(...).agg(name=('column', aggfunc))
#
#   return super().aggregate(arg, *args, **kwargs)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-105-346cde3c6b10> in <module>
#       1 #pivot_df.groupby(['Country_Region']).agg({pivot_df.columns.get_level_values(1)[3] : np.sum})
# ----> 2 pivot_df.groupby(['Country_Region']).agg({tuple(pivot_df.Cases.Confirmed) : np.sum})
#
# D:\Anaconda\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, arg, *args, **kwargs)
#    1453     @Appender(_shared_docs["aggregate"])
#    1454     def aggregate(self, arg=None, *args, **kwargs):
# ...

# %%
pivot_df.groupby(['Country_Region']).agg({pivot_df[['Cases','Confirmed']] : np.sum})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-118-b37eeee93d2b> in <module>
# ----> 1 pivot_df.groupby(['Country_Region']).agg({pivot_df[['Cases','Confirmed']] : np.sum})
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# -> 2986             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2987
#    2988         # take() does not accept boolean indexers
#
# D:\Anaconda\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# ...

# %%
#pivot_df_drop_level=pivot_df.copy()

# %%
#pivot_df_drop_level=pivot_df_drop_level.droplevel('Confirmed')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-91-73fea1dbfff3> in <module>
# ----> 1 pivot_df_drop_level=pivot_df_drop_level.droplevel('Confirmed')
#
# D:\Anaconda\lib\site-packages\pandas\core\generic.py in droplevel(self, level, axis)
#     815         """
#     816         labels = self._get_axis(axis)
# --> 817         new_labels = labels.droplevel(level)
#     818         result = self.set_axis(new_labels, axis=axis, inplace=False)
#     819         return result
#
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in droplevel(self, level)
#    1647             level = [level]
#    1648
# -> 1649         levnums = sorted(self._get_level_number(lev) for lev in level)[::-1]
#    1650
#    1651         if len(level) == 0:
#
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in <genexpr>(.0)
#    1647             level = [level]
#    1648
# ...

# %%
#pivot_df_drop_level.index.unique('Country_Region')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-96-ad59ac2730c4> in <module>
# ----> 1 pivot_df_drop_level.index.unique('Country_Region')
#
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in unique(self, level)
#    2154     def unique(self, level=None):
#    2155         if level is not None:
# -> 2156             self._validate_index_level(level)
#    2157         result = super().unique()
#    2158         return self._shallow_copy(result)
#
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in _validate_index_level(self, level)
#    1556             raise KeyError(
#    1557                 "Requested level ({}) does not match index name ({})".format(
# -> 1558                     level, self.name
#    1559                 )
#    1560             )
#
# KeyError: 'Requested level (Country_Region) does not match index name (None)'
